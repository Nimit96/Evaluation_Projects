# %% [markdown]
# # Baseball Case Study
# ### Problem Statement:
# #### This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('max_columns',None)

# %% [markdown]
# ##### -- Input features:
# R - Runs,
# AB - At Bats,
# H - Hits,
# 2B - Doubles,
# 3B - Triples,
# HR - Homeruns,
# BB - Walks,
# SO - Strikeouts,
# SB - Stolen Bases,
# RA - Runs Allowed,
# ER - Earned Runs,
# ERA - Earned Run Average (ERA),
# SHO - Shutouts,
# SV - Saves,
# CG - Complete Games and
# E - Errors
#
# ##### -- Output: Number of predicted wins - (W)

# %%
#importing csv
data=pd.read_csv('baseball.csv')
data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# In dataset all the columns is in numeric values, there are no categorical columns in the dataset. It contains of both features and label.
# Label 'W' which is number of wins made by the baseball teams is what we need to predict

# %% [markdown]
# ### Data PreProcessing(Data Cleaning)

# %%
#checking for the shape of the data
data.shape
# Out:
# (30, 17)

# %% [markdown]
# 30 rows and 17 columns

# %%
#checking for nulls
data.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# No null values in the dataset

# %%
#checking for info of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# All the columns are of int type except ERA since it is a mean value thus float type

# %%
#checking for stats
data.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# From stats:
# Minimum no of wins: 63
# The average wins: 80
# Maximum wins: 100
# We can corelate for other columns.
# Data seems to be normally distributed comparing with stats, there is no much skewness.
# We will check the skewness by using some of the visualisation techniques later.

# %%
#Checking for uniqueness in the data
data.apply(lambda x: len(x.unique()))
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# We have some of features for getting the predicted label.But some of them are missing , using some of the data from our features lets create some more columns which are important for our prediction and see how the dataset changes accordingly.

# %%
# Batting Average
#Creating extra column Batting Average it means no of hits divided by at bats
data['BA']=data['H']/data['AB']

# %% [markdown]
# Batting average = number of hits/at bats will drop the columns of H and AB

# %%
#Singles
# H is the number of hits which is the combination of 1b,2b,3b,home runs 
data['1B']=data['H']-(data['2B']+data['3B']+data['HR'])

# %% [markdown]
# Finding singles inorder to find total bases the singles is missing in the columns hits is the combination of singles,doubles,triples so by using others information am finding singles which is an extra column

# %% [markdown]
# H is the number of hits which is the combination of 1b,2b,3b,home runs so from them am finding 1B Because for wins 1B is enough for a batsman the 2B,3B,home runs are important beacuse that decides weather he have played all the games are not but for our prediction only 1B is enough so dropping remaining column.

# %%
#Total Bases 
#adding extra columns which increases the winning rate
data['Total Bases']=(1*data['1B']+2*data['2B']+3*data['3B']+4*data['HR'])

# %% [markdown]
# Total Bases=total bases/at bats

# %%
#Slag%
data['slag%']=data['Total Bases']/data['AB']

# %% [markdown]
# Slagging is measured by = Total Bases/At Bats

# %%
#Dropping the columns which are not used for prediction
data.drop(columns=['2B','3B','1B','Total Bases','CG','SV','SHO'],axis=1,inplace=True)

# %% [markdown]
# Above are listed features which are required for our label prediction so after considering them what all the features required am keeping them and dropping the other features which are not required for the prediction

# %%
data.head()
# Out:
#     W    R    AB     H   HR   BB    SO   SB   RA   ER   ERA    E        BA  \
# 0  95  724  5575  1497  139  383   973  104  641  601  3.73   88  0.268520
# 1  83  696  5467  1349  156  439  1264   70  700  653  4.07   86  0.246753
# 2  81  669  5439  1395  141  533  1157   86  640  584  3.67   79  0.256481
# 3  76  622  5533  1381  136  404  1231   68  701  643  3.98  101  0.249593
# 4  74  689  5605  1515  151  455  1259   83  803  746  4.64   86  0.270294
#
#       slag%
# 0  0.412197
# 1  0.399122
# 2  0.400625
# 3  0.380083
# 4  0.420161

# %%
data.shape
# Out:
# (30, 14)

# %% [markdown]
# ### Visualisation

# %%
#Lets check the distribution of the data in the columns using distribution plot
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in data:
    if plotnumber<=18:
        ax=plt.subplot(6,3,plotnumber)
        plt.hist(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From histogram plot we can see how the data distributed in columns the max and min values of the particualr data can be seen by using histogram plot.

# %%
#Lets check the distribution of the data in the columns using distribution plot
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in data:
    if plotnumber<=18:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# The data seems to be normally distributed there is only some skewness in the columns so lets go head and plot the box plot and visualise and check for the outliers

# %%
#Lets check the boxplot and visualise
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in data:
    if plotnumber<=18:
        ax=plt.subplot(6,3,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
data.skew() #to check skewness.
# Out:
# W        0.047089
# R        1.200786
# AB       0.183437
# H        0.670254
# HR       0.516441
# BB       0.158498
# SO      -0.156065
# SB       0.479893
# RA       0.045734
# ER       0.058710
# ERA      0.053331
# E        0.890132
# BA       0.651283
# slag%    0.399542
# dtype: float64

# %% [markdown]
# There are some outliers present in some of the columns lets try removing the outliers using Z Score

# %% [markdown]
# ### Z Score

# %%
#importing the stats from the scipy library
from scipy import stats
#lets remove our ouliers using z_score
z=np.abs(stats.zscore(data))#abs=absolute numberprint(z)
print(z)
# Out:
# [[1.36540860e+00 6.19077968e-01 8.47731264e-01 1.66368512e+00
#   7.87298598e-01 1.53490242e+00 2.69762957e+00 9.13883291e-01
#   6.66233927e-01 5.05110079e-01 5.06955186e-01 4.61469635e-01
#   1.75149719e+00 4.11027026e-01]
#  [1.97838300e-01 1.34431656e-01 7.11093535e-01 9.70680764e-01
#   2.43966683e-01 5.36591904e-01 1.54878442e-01 6.01825582e-01
#   1.65970766e-01 2.48929848e-01 2.54597523e-01 6.07196888e-01
#  [1.74811219e+00 1.07718413e+00 1.83787368e-01 5.25686526e-01
#   1.07494491e+00 1.46359453e+00 2.52902772e-01 2.00608527e-01
#   1.70343367e+00 1.64100356e+00 1.64331129e+00 1.65157553e+00
#   7.27587028e-01 1.22663938e+00]
#  [1.07351602e+00 3.67523453e-01 1.89464570e+00 1.02408007e+00
#   7.46815043e-01 1.67395282e+00 9.60638438e-02 1.09220198e+00
#   1.31507148e+00 1.20114693e+00 1.15651485e+00 1.40869678e+00
#   5.48495787e-01 4.34079484e-01]
#  [2.95135825e-01 1.34431656e-01 7.03395634e-01 1.46788766e+00
#   8.83180700e-01 2.15706380e-01 8.74377027e-01 4.23506891e-01
#   8.63706227e-01 5.63113151e-01 5.29353795e-01 1.19010590e+00
#   1.56640820e+00 8.49364470e-02]
#  [1.91351799e-01 5.49842780e-01 1.91581492e+00 1.61028582e+00
#   3.07888085e-01 3.72583748e-01 6.25395228e-01 2.16211413e+00
#   3.49337902e-01 3.35934455e-01 1.87401696e-01 6.07196888e-01
#   1.24996596e+00 5.29531126e-01]
#  [6.77839422e-01 6.61773000e-01 8.55429164e-01 1.41567500e+00
#   4.99652290e-01 7.68342561e-01 7.72431723e-01 6.68695091e-02
#   6.03230859e-01 2.77931383e-01 2.99394742e-01 1.70015129e-01
#   1.45644961e+00 1.05508700e+00]
#  [1.26162457e+00 8.44092327e-01 8.04430575e-01 1.34328927e+00
#   7.14854342e-01 1.44576756e+00 3.41124670e-01 6.01825582e-01
#   2.19711442e+00 2.36604195e+00 2.42726261e+00 4.85757510e-02
#   1.36922655e+00 1.48999530e+00]]

# %%
#Rows having outliers more than 3 standard deviation
print('Row Numbers \n',np.where(z>3)[0])
# Out:
# Row Numbers
#  [5]

# %%
#dropping some of the data of rows which r having outliers
index=(np.where(z>3)[0])
data=data.drop(data.index[index])

# %%
data.shape
# Out:
# (29, 14)

# %% [markdown]
# After checking the shape again there is a outlier present in only one row so that got deleted so now row shape got changed

# %% [markdown]
# ### Correlation

# %%
#Plotting the heat map to check the correlation with the features to features and label to features
df_corr=data.corr().abs()
plt.figure(figsize=(20,10))
sns.heatmap(df_corr,vmin=-1,vmax=1,annot=True,square=True,center=0,fmt='.3g',linewidth=.1)
plt.tight_layout()

# %% [markdown]
# Our label is highly correlated with three features which are runs allowed,Earned runs,Earned average runs,saves and very lessely correlated with error.The feature to feature corrleation is present in Runs allowed,Earned average runs,Earned runs all tose are corelated with the labels and features,also there is a multicollinearity problem exis if the accuracy score is not good then i will go ahead and delete one of the column which is highly corelated with the other.CG is the feature which is very very less correlated with label.so that doesnot help us in model building am deledting that column too.

# %% [markdown]
# ### Splitting Features and Label

# %%
#Am seperating the features and labels
#also in our data set there are features which are highly corelated with eath other am deleting that feature and a feature which is not corelated with label
x=data.drop(columns=['W'],axis=1)
y=data['W']

# %%
#plotting the histogram plot 
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in data:
    if plotnumber<=18:
        ax=plt.subplot(6,3,plotnumber)
        plt.scatter(y,data[column])
        plt.xlabel(column,fontsize=20)
        plt.ylabel('W',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From scatter plot we can see the relation between the label and the columns.In some of the columns the label is highly correlated with the features.Label is highly correlated with Runs allowed,Earned runs,average earned runs so the data is falling from left to right which means highly correlated.But with the features slag%,BB,HR the data points are falling from right to left which means there are less correlated.In remaining features the data is in random distribution which means there are not at all corelated with the label.

# %% [markdown]
# ### SkewNess

# %%
#Checking for skewness in the data
x.skew()
# Out:
# R       -0.215364
# AB       0.169573
# H        0.783772
# HR       0.450862
# BB       0.151193
# SO      -0.233815
# SB       0.494966
# RA       0.018155
# ER       0.018461
# ERA      0.016693
# E        0.840271
# BA       0.735645
# slag%   -0.253706
# dtype: float64

# %% [markdown]
# The skewness should be in the range of -0.5 to +0.5 so which has more than 0.5 for that columns am applying log transformation.

# %% [markdown]
# ### Data Transformation

# %%
#Applying log transformation
x['H']=np.log(1+x['H'])
x['E']=np.log(1+x['E'])
x['BA']=np.log(1+x['BA'])

# %% [markdown]
# ### Scaling

# %%
#importing Standard Scaler
from sklearn.preprocessing import StandardScaler
#scailing the data
scaler=StandardScaler()
x=scaler.fit_transform(x)
x
# Out:
# array([[ 0.95939835,  0.83008422,  1.72372599, -0.76586314, -1.53635899,
#         -2.72762331,  0.9059529 , -0.66451353, -0.51114812, -0.51138828,
#         -0.43573324,  1.88268689,  0.58595253],
#        [ 0.33114717, -0.70283074, -0.94984589, -0.18138864, -0.49502051,
#          0.12189552, -0.58531515,  0.15463823,  0.23216082,  0.23895226,
#         -0.59810993, -0.92161844, -0.2217725 ],
#        [-0.27466646, -1.10025314, -0.08870013, -0.69710144,  1.25294051,
#         -0.9258657 ,  0.11645805, -0.67839746, -0.75415297, -0.64380131,
#         -1.19738162,  0.33763854, -0.12891809],
#        [-1.32923093,  0.23395062, -0.34774692, -0.8690057 , -1.14585706,
#         -0.20124579, -0.6730368 ,  0.16852216,  0.08921679,  0.04033271,
#          0.53829069, -0.55295361, -1.39789573],
#        [ 0.17408438,  1.25589393,  2.03070817, -0.35329291, -0.19749523,
#          0.07293472, -0.01512442,  1.58468284,  1.56154027,  1.4968761 ,
#         -0.59810993,  2.10913789,  1.07788184],
#        [ 1.85690002,  0.71653496, -0.05190567,  1.74393914,  1.64344245,
#         -0.24041443, -0.89234092,  0.12687038,  0.21786641,  0.1506769 ,
#         -0.04523896, -0.3780458 ,  1.12189214],
#        [ 0.71258538, -0.44734492, -0.55313135,  1.9158434 , -0.88552244,
#          0.7779703 , -1.7256966 ,  0.05745074,  0.1321    ,  0.19481458,
#         -1.3782588 , -0.52977779,  1.10512887],
#        [-0.83560501, -0.44734492, -0.31057999,  0.19680075, -0.5508065 ,
#          0.57233492,  0.16031888, -0.6506296 , -0.46826492, -0.48931944,
#          0.10517222, -0.22280715,  0.19286577],
#        [ 1.49789935,  1.75267193,  1.68938942, -0.00948437,  0.23019736,
#          0.21981713,  0.2041797 ,  1.66798641,  1.60442347,  1.6072203 ,
#          1.57929474, -0.69375755, -1.30269908],
#        [-0.31954155, -1.86671063, -1.00702261,  0.88441781,  1.81080042,
#          0.06314255, -1.06778422, -1.30317423, -1.19727945, -1.15138462,
#         -1.5638346 , -0.50625372,  0.61253796],
#        [ 0.33114717,  0.68814765,  1.53430459, -0.8690057 , -0.16030457,
#         -0.90628138,  0.42348383, -0.85888852, -0.56832573, -0.53345712,
#         -1.2872478 ,  1.69173784,  0.20988601],
#        [ 0.86964818,  1.88041485,  1.67220391, -0.25015035,  0.45334132,
#          0.59191925,  2.134056  ,  0.3351293 ,  0.31792723,  0.17274574,
#         -0.59810993,  1.36475461,  0.72261831],
#        [-0.70097976, -0.84476732, -1.43025099, -0.45643546, -0.7367598 ,
#          0.73880166, -0.05898525,  0.58504001,  0.26074962,  0.28308994,
#         -0.12164896, -1.45910409, -1.10485495],
#        [ 1.25108639,  0.78750325,  1.41303273,  0.85003696, -1.44338234,
#          0.30794658,  0.59892713,  2.1539239 ,  2.31914361,  2.37962968,
#          0.10517222,  1.48806539,  1.83028114]])

# %% [markdown]
# ### Train Test Split

# %%
#splitting the data into train,test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=16)

# %% [markdown]
# ### Regression Algorithms

# %%
#importing the algorithms
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
#lets import some of the evaluation metrics for classification problem
from sklearn.metrics import mean_squared_error,mean_absolute_error
#importing grid search cv for hyper parameter tuning and cross validation score for testing our model
from sklearn.model_selection import GridSearchCV,cross_val_score

# %% [markdown]
# ### Linear Regression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predicting

# %%
y_pred=lr.predict(x_test)

# %% [markdown]
# ### Evaluation Metrics

# %%
#Checking the scores
lr.score(x_test,y_test)
# Out:
# 0.7068159488784846

# %%
#Checking the cross validation score
np.mean(cross_val_score(lr,x,y,cv=5))
# Out:
# 0.5542235357744926

# %%
#Mean squared value
mean_squared_error(y_test,y_pred)
# Out:
# 14.948767051010597

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3.1706711458106094

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 3.866363543565271

# %% [markdown]
# ### KNeighbors Regressor

# %%
#Knn
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# ### Predicting

# %%
y_pred=knn.predict(x_test)
y_pred
# Out:
# array([86.2, 78.6, 79. , 77.8, 87.8, 73.4, 77.8, 77.8, 71.2])

# %% [markdown]
# ### Evaluation Metrics

# %%
knn.score(x_test,y_test)
# Out:
# 0.4430895883777237

# %%
np.mean(cross_val_score(knn,x,y,cv=5))
# Out:
# -0.1456152599697314

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 28.39555555555557

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 4.6000000000000005

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 5.328748028904686

# %% [markdown]
# ### Random Forest Regressor

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ### Prediction

# %%
y_pred=rf.predict(x_test)
y_pred
# Out:
# array([83.33, 73.49, 73.42, 85.98, 90.83, 73.4 , 83.85, 84.52, 82.99])

# %% [markdown]
# ### Evaluation Metrics

# %%
rf.score(x_test,y_test)
# Out:
# 0.19054980629539953

# %%
np.mean(cross_val_score(rf,x,y,cv=5))
# Out:
# -0.5341389397715863

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 41.271966666666664

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 5.105555555555556

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 6.424326164405623

# %% [markdown]
# ### Support Vector Regressor

# %%
svm=SVR()
svm.fit(x_train,y_train)
# Out:
# SVR()

# %% [markdown]
# ### Prediction

# %%
y_pred=svm.predict(x_test)

# %% [markdown]
# ### Evaluation Metrics

# %%
svm.score(x_test,y_test)*100
# Out:
# -24.449379509302904

# %%
np.mean(cross_val_score(svm,x,y,cv=5))
# Out:
# -0.2993846024539454

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 63.45381942881741

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 6.448514875894489

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 7.965790571488646

# %% [markdown]
# ### Extreme gradient boost Regresser

# %%
xgb=XGBRegressor()
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Prediction

# %%
y_pred=xgb.predict(x_test)

# %% [markdown]
# ### Evaluation Metrics

# %%
xgb.score(x_test,y_test)
# Out:
# 0.7173275350374294

# %%
cross=cross_val_score(xgb,x,y,cv=5)
print(np.mean(cross))
# Out:
# -0.7659506041416975

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 14.412805929573047

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3.2561781141493054

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 3.796420146608255

# %% [markdown]
# ### Final Model

# %% [markdown]
# Have tried best possible ways to acheive the good score but not able too.Even By removing the correlated columns which has multicollinearity problem but the score is remaining almost same with slight diference after checking all the algorithms performance the Extreme gradient Boost  is only giving little better score and cross validation score so am going with the Extreme Gradient boost regressor as my model.

# %% [markdown]
# ### Extreme Gradient Boost Regressor

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
#Assigning values to grid search cv to get get best params
grid_param={'max_depth':range(5,10,1),'learning_rate':[0.1,0.2,0.3],'gamma':[0,0.1,0.2],'min_child_weight':[1,2,3,4],"n_estimators":[10,50,100],'n_jobs':range(-1,1,1),'booster':['gbtree']}

# %%
grid=GridSearchCV(xgb,param_grid=grid_param)

# %%
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0, gpu_id=-1,
#                                     importance_type='gain',
#                                     interaction_constraints='',
#                                     learning_rate=0.300000012, max_delta_step=0,
#                                     max_depth=6, min_child_weight=1,
#                                     missing=nan, monotone_constraints='()',
#                                     n_estimators=100, n_jobs=4,
#                                     num_parallel_tree=1, random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, subsample=1,
#                                     tree_method='exact', validate_parameters=1,
#                                     verbosity=None),
#              param_grid={'booster': ['gbtree'], 'gamma': [0, 0.1, 0.2],
#                          'learning_rate': [0.1, 0.2, 0.3],
#                          'max_depth': range(5, 10),
#                          'min_child_weight': [1, 2, 3, 4],
#                          'n_estimators': [10, 50, 100],
#                          'n_jobs': range(-1, 1)})

# %%
grid.best_params_
# Out:
# {'booster': 'gbtree',
#  'gamma': 0,
#  'learning_rate': 0.3,
#  'max_depth': 5,
#  'min_child_weight': 4,
#  'n_estimators': 10,
#  'n_jobs': -1}

# %% [markdown]
# ### Extreme Gradient Boost Regressor

# %%
xgb=XGBRegressor(booster='gbtree',gamma=0,learning_rate=0.3,min_child_weight=1,n_jobs=-1, n_estimators=100,max_depth=6)
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.3, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=-1, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Prediction

# %%
y_pred_test=xgb.predict(x_test)
y_pred_test
# Out:
# array([83.05306 , 78.88358 , 81.07875 , 85.004425, 83.29526 , 66.305855,
#        75.3275  , 83.00689 , 76.954575], dtype=float32)

# %% [markdown]
# ### Evaluation Metrics

# %%
xgb.score(x_test,y_test)
# Out:
# 0.7173275350374294

# %%
cross=cross_val_score(xgb,x,y,cv=5)
print(np.mean(cross))
# Out:
# -0.7659506041416975

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 14.412805929573047

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3.2561781141493054

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 3.796420146608255

# %% [markdown]
# Not much change after Hyper Parameter tuning in the score and cross validation score.Even though compared to all the other models the Extreme Graidient boosting Regressor is giving good performance so going with this model as final model building

# %% [markdown]
# ### Model Saving

# %%
#importing pickle
import pickle
filename='BaseBall Prediction.pkl'
pickle.dump(xgb,open(filename,'wb'))

# %% [markdown]
# ### Conclusion

# %%
a=np.array(y_test)
predicted=np.array(y_pred_test)
df=pd.DataFrame({'Original':a,'Predicted':predicted},index=range(len(a)))
df
# Out:
#    Original  Predicted
# 0        81  83.053062
# 1        78  78.883583
# 2        76  81.078751
# 3        80  85.004425
# 4        90  83.295258
# 5        64  66.305855
# 6        71  75.327499
# 7        85  83.006889
# 8        76  76.954575

# %% [markdown]
# ### Plotting

# %%
#Curve for actual and predicted value
plt.scatter(y_test,y_pred_test)
plt.xlabel('Actual No of Wins')
plt.ylabel('Predicted No of Wins')
plt.title('Actual Wins V/s Predicted Wins')
plt.show()
